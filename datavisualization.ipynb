# %% [markdown]
# ## Seaborn

# %%
## Seaborn is a highleval ploting graph..it builds upon matplotlib..which have advanced ploting function..if you wanna graph more attractive you can seaborn library

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
df=sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
custom_bins=[0,10,20,30,40,50,60]
sns.histplot(data=df,x="total_bill",bins=custom_bins)
plt.show()
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(data=df,x='total_bill',kde=True,stat='probability')
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='Probability'>

# %%
sns.scatterplot(data=df,x="total_bill",y="tip")
plt.show()

# %%
sns.barplot(x="day",y="tip",data=df)
plt.xlabel("day")
plt.ylabel("Tip")
plt.title("Relationship between total bil and tips") 
plt.show()
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.barplot(x="day",y="tip",data=df,ci=None)
plt.xlabel("day")
plt.ylabel("Tip")
plt.title("Relationship between total bil and tips") 
plt.show()
# Out:
# C:\Users\mehza\AppData\Local\Temp\ipykernel_13856\139096557.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="day",y="tip",data=df,ci=None)
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.barplot(x="day",y="tip",data=df,ci=None,palette='pastel')
plt.xlabel("day")
plt.ylabel("Tip")
plt.title("Relationship between total bil and tips") 
plt.show()
# Out:
# C:\Users\mehza\AppData\Local\Temp\ipykernel_13856\538237282.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="day",y="tip",data=df,ci=None,palette='pastel')
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.barplot(x="day",y="tip",data=df,ci=None,palette='pastel',saturation=0.1)
plt.xlabel("day")
plt.ylabel("Tip")
plt.title("Relationship between total bil and tips") 
plt.show()
# Out:
# C:\Users\mehza\AppData\Local\Temp\ipykernel_13856\124449668.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="day",y="tip",data=df,ci=None,palette='pastel',saturation=0.1)
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
#  #### a parameter in seaborn plot functions that allow you to specify a categorical variable.

# %%
##lineplot.....used to visualize that trend of a variable over time
sns.lineplot(x="tip",y="total_bill",data=df)
plt.show()
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### strip plot( sns.stripplot):display individual data points along with a categorical variable
# ## #swarm plot(sns.swarmplot):similar to strip plot  but points are adjusted to avoid overlap

# %%
sns.stripplot(x="sex",y="total_bill",data=df)
plt.show()
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.swarmplot(x="day",y="total_bill",data=df)
plt.show()
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.swarmplot(x="total_bill",y="day", hue='time',orient='h',data=df)
plt.show()
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.set_theme(style='whitegrid')
sns.swarmplot(x="total_bill",y="day", hue='time',orient='h',data=df)
plt.show()
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.set_theme(style='darkgrid')
sns.swarmplot(x="total_bill",y="day", hue='time',orient='h',data=df)
plt.show()
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.set_theme(style='whitegrid')#get white grid
sns.set_style('darkgrid')
sns.swarmplot(x="total_bill",y="day", hue='time',orient='h',data=df)
plt.show()
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.stripplot(x="sex",y="total_bill",data=df,linewidth=0.7,edgecolor='green')
plt.show()
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.set_style('dark')
sns.stripplot(x="sex",y="total_bill",data=df,linewidth=0.5,edgecolor='green')
plt.show()
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### box plot(sns.boxplot):summarize the distributionof the numeric variable

# %%
sns.boxplot(x='day',y='total_bill',data=df)
plt.show()
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# #### outliers are data points that are significally different from the rest of the data,they lie away from the group of main points

# %% [markdown]
# #MINIMUM:THE SMALLEST VALUE IN THE DATASET
# #FIRST QUARTILE:THE MEADIAN OF THE LOWER HALFOF THE DATA(EXCLUDING THE MEADIAN IF THE MEMBER OF OBSERVATION IS ODD)

# %%
sns.boxplot(x='day',y='total_bill',data=df,hue='size')
plt.show()
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.boxplot(x="day",y="total_bill",data=df,hue="size",linewidth=1)
plt.show()
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.boxplot(x='day',y='total_bill',data=df,linewidth=1,showmeans=True)
plt.show()
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.boxplot(x='day',y='total_bill',data=df,linewidth=1,showmeans=True,meanprops={"marker": "+","mec":"black","markersize":10})
plt.show()
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# #### violinplots (sns.violinplot):display the distribution of a numeric variable for each catogory using kernal density estimation

# %%
sns.violinplot(x='day',y='total_bill',data=df)
plt.show()
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.violinplot(x='day',y='total_bill',inner='quart',data=df)
plt.show()
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.violinplot(x='day',y='total_bill',inner='quart',hue='smoker',split=True,data=df)
plt.show()
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.violinplot(x="day",y="total_bill",hue="size",inner='point',data=df)
plt.show()
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# # countplot

# %%
y=df.groupby('sex')['smoker'].value_counts()
print(y)
sns.countplot(x="sex",hue='smoker',data=df)
0plt.show()
# Out:
# sex     smoker
# Male    No        97
#         Yes       60
# Female  No        54
#         Yes       33
# Name: count, dtype: int64
# C:\Users\mehza\AppData\Local\Temp\ipykernel_13856\3471496481.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   y=df.groupby('sex')['smoker'].value_counts()
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.countplot(x='sex',hue="smoker",paltte='muted',facecolor=(0,0),data=df)
plt.show()
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 sns.countplot(x='sex',hue="smoker",palatte='muted',facecolor=(0,0),data=df)
#       2 plt.show()
#
# File ~\anaconda2\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# ...

# %%
sns.relplot(data=df, x="total_bill", y="tip", hue="day")

# %%
sns.relplot(data=df, x="total_bill", y="tip", hue="day", col="time")

# %%
sns.relplot(data=df, x="total_bill", y="tip", hue="day", col="time",row="sex")

# %%
sns.relplot(data=df, x="total_bill", y="tip",kind="line")
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### categorical plot

# %%
###that can create variety of plot types depending on the value provided to the kind parameter
sns.catplot(x="sex",y="tip", kind="bar",data=df)
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# # regplot

# %%
sns.regplot(data=df,x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.regplot(data=df,x="total_bill",y="tip",logistic=True)
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\statsmodels\genmod\families\links.py:198: RuntimeWarning: overflow encountered in exp
#   t = np.exp(-z)
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### kdeplot

# %%
sns.kdeplot(data=df,x="total_bill",y="tip")
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.kdeplot(data=df,x="total_bill",y="tip",shade="true",color="y")
# Out:
# C:\Users\mehza\AppData\Local\Temp\ipykernel_13152\2521840017.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=true`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df,x="total_bill",y="tip",shade="true",color="y")
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.kdeplot(data=df,x="total_bill",y="tip",color="y")
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
#  # pairplot

# %%
sns.pairplot(df)
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # joinplot

# %%
sns.jointplot(data=df,x="total_bill",y="tip",kind="reg")
# Out:
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mehza\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # correlation

# %%
#it me9ns the relationshio between two numerical variable
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 #it me9ns the relationshio between two numerical variable
# ----> 2 df.corr()
#
# File ~\anaconda2\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda2\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for column in ['day','time','sex','smoker']:
    df[column]=le.fit_transform(df[column])
df
# Out:
#      total_bill   tip  sex  smoker  day  time  size
# 0         16.99  1.01    0       0    2     0     2
# 1         10.34  1.66    1       0    2     0     3
# 2         21.01  3.50    1       0    2     0     3
# 3         23.68  3.31    1       0    2     0     2
# 4         24.59  3.61    0       0    2     0     4
# ..          ...   ...  ...     ...  ...   ...   ...
# 239       29.03  5.92    1       0    1     0     3
# 240       27.18  2.00    0       1    1     0     2
# 241       22.67  2.00    1       1    1     0     2
# 242       17.82  1.75    1       0    1     0     2
# 243       18.78  3.00    0       0    3     0     2
#
# [244 rows x 7 columns]

# %%
corr=df.corr()
corr
# Out:
#             total_bill       tip       sex    smoker       day      time  \
# total_bill    1.000000  0.675734  0.144877  0.085721 -0.043550 -0.183118
# tip           0.675734  1.000000  0.088862  0.005929 -0.011548 -0.121629
# sex           0.144877  0.088862  1.000000  0.002816 -0.078292 -0.205231
# smoker        0.085721  0.005929  0.002816  1.000000 -0.282721 -0.054921
# day          -0.043550 -0.011548 -0.078292 -0.282721  1.000000  0.638019
# time         -0.183118 -0.121629 -0.205231 -0.054921  0.638019  1.000000
# size          0.598315  0.489299  0.086195 -0.133178  0.069510 -0.103411
#
#                 size
# total_bill  0.598315
# tip         0.489299
# sex         0.086195
# smoker     -0.133178
# day         0.069510
# time       -0.103411
# size        1.000000

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
corr.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
 sns.heatmap(corr,vmin=-1,vmax=1)
# Out:
# <Axes: >

# %%
 sns.heatmap(corr,vmin=-1,vmax=1,cmap='viridis')
# Out:
# <Axes: >

# %%
sns.heatmap(corr,vmin=-1,vmax=1,cmap='Pastel1_r',linewidth=0.2,linecolor='black')
# Out:
# <Axes: >

# %%
sns.heatmap(corr,vmin=-1,vmax=1,annot=True,fmt='.0f',annot_kws={'size':20},cmap='Pastel1_r',linewidth=0.2,linecolor='black')
# Out:
# <Axes: >

# %%
sns.heatmap(corr,vmin=-1,vmax=1,annot=True,fmt='.0f',annot_kws={'size':20},cmap='Pastel1_r',linewidth=0.2,linecolor='black',xticklabels=False,yticklabels=False)
# Out:
# <Axes: >

# %%
sns.heatmap(corr,vmin=-1,vmax=1,annot=True,fmt='.0f',annot_kws={'size':20},cmap='Pastel1_r',linewidth=0.2,linecolor='black',xticklabels=False,yticklabels=False,cbar=False)
# Out:
# <Axes: >
